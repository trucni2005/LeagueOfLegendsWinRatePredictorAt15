# %%
from selenium import webdriver
from bs4 import BeautifulSoup

url = 'https://www.leagueofgraphs.com/match/kr/6468468401'

# Khởi tạo trình duyệt Chrome
driver = webdriver.Chrome()

# Mở trang web
driver.get(url)

# Chờ cho trang web tải xong
driver.implicitly_wait(10)

# Lấy HTML của trang web
html = driver.page_source

# Phân tích HTML bằng BeautifulSoup
soup = BeautifulSoup(html, 'html.parser')

print(soup)
# Out:
# <html lang="en" xmlns="http://www.w3.org/1999/xhtml"><head>
# <link href="https://fonts.googleapis.com/css?family=Open+Sans:300,400,500,700" media="all" onload="this.media='all'" rel="stylesheet" type="text/css"/> <link href="//lolg-cdn.porofessor.gg/style.css?v=1682510184" rel="stylesheet" type="text/css"/>
# <link href="//lolg-cdn.porofessor.gg/style.sprite.css?v=38ab2c463867fdb168ff4e852c916f44" rel="stylesheet" type="text/css"/>
# <script async="" src="https://www.google-analytics.com/plugins/ua/linkid.js" type="text/javascript"></script><script async="" defer="" src="https://static.developer.riotgames.com/js/rgea.min.js" type="text/javascript"></script><script async="" src="//www.google-analytics.com/analytics.js"></script><script async="" src="https://sb.scorecardresearch.com/cs/20631572/beacon.js"></script><script src="//lolg-cdn.porofessor.gg/jquery.js?v=3"></script>
# <meta content="width=device-width, initial-scale=1.0" name="viewport"/>
# ...

# %%
div_tags = soup.find_all('div', {'class': 'relative'})
i = 0
for div_tag in div_tags:
    a_tag = div_tag.find('a')
    if a_tag:
        img_tag = a_tag.find('img')
        if img_tag:
            i = i+1
            champion_name = img_tag['alt']
print("Blue: ", champion_blue)
print("Red: ", champion_red)
# Out:
# Blue:  ["K'Sante", 'Gragas', 'Galio', 'Xayah', 'Rakan']
# Red:  ['Gnar', 'Lee Sin', 'Akali', 'Ashe', 'Lulu']
